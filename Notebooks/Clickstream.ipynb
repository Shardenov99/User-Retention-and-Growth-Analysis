# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('click_stream.csv')
df['event_time'] = pd.to_datetime(df['event_time'])

# %%
df.shape
# Out:
# (12833602, 6)

# %%
df['event_time'].min()
# Out:
# Timestamp('2016-06-30 22:59:36.254358+0000', tz='UTC')

# %%
df['event_time'].max()
# Out:
# Timestamp('2022-08-01 00:49:59.408424+0000', tz='UTC')

# %% [markdown]
# ### Filter the data so we only use events which occured during the past year

# %%
df = df[(df['event_time'] >= '2021-08-01') & (df['event_time'] <= '2022-07-31')]

# %%
df.shape
# Out:
# (4793008, 6)

# %% [markdown]
# ### Double check that everything is correct and is working.

# %%
df['event_time'].min()
# Out:
# Timestamp('2021-08-01 00:00:09.598036+0000', tz='UTC')

# %%
df['event_time'].max()
# Out:
# Timestamp('2022-07-30 23:59:56.710139+0000', tz='UTC')

# %%
df.dtypes
# Out:
# session_id                     object
# event_name                     object
# event_time        datetime64[ns, UTC]
# event_id                       object
# traffic_source                 object
# event_metadata                 object
# dtype: object

# %%
df.isnull().sum()
# Out:
# session_id              0
# event_name              0
# event_time              0
# event_id                0
# traffic_source          0
# event_metadata    3274293
# dtype: int64

# %% [markdown]
# ### Split the column metadata into 3 separate columns - ProductID, Quantity and Item Price.

# %%
import ast

def extract_metadata(meta, key):
    if pd.isna(meta):
        return None
    if isinstance(meta, str):
        meta = ast.literal_eval(meta)
    return meta.get(key, None)

df['product_id'] = df['event_metadata'].apply(lambda x: extract_metadata(x, 'product_id'))
df['quantity'] = df['event_metadata'].apply(lambda x: extract_metadata(x, 'quantity'))
df['item_price'] = df['event_metadata'].apply(lambda x: extract_metadata(x, 'item_price'))
df['payment_status'] = df['event_metadata'].apply(lambda x: extract_metadata(x, 'payment_status'))

# %%
df = df.drop(columns=['event_metadata'])

# %%
df['event_name'].value_counts()
# Out:
# event_name
# CLICK          968370
# HOMEPAGE       930962
# SCROLL         655255
# ADD_TO_CART    637452
# ITEM_DETAIL    500132
# SEARCH         464663
# BOOKING        314839
# PROMO_PAGE     219574
# ADD_PROMO      101761
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                                 session_id   event_name  \
# 1734  9586a822-62e6-43e3-80a8-604e817daad4     HOMEPAGE
# 1735  9586a822-62e6-43e3-80a8-604e817daad4  ADD_TO_CART
# 1736  9586a822-62e6-43e3-80a8-604e817daad4      BOOKING
# 1737  9586a822-62e6-43e3-80a8-604e817daad4       SCROLL
# 1738  9586a822-62e6-43e3-80a8-604e817daad4       SEARCH
#
#                            event_time                              event_id  \
# 1734 2021-08-04 07:31:35.425431+00:00  a78f83d7-489c-4123-808b-9fca01c51847
# 1735 2021-08-04 15:25:09.425431+00:00  f79f8b9f-c044-41da-add5-ed2e511585ce
# 1736 2021-08-06 06:57:08.425431+00:00  544bfa6a-9bf3-410a-b7c5-ad430ab756ae
# 1737 2021-08-04 15:24:06.425431+00:00  2553f0a6-80cf-4df5-b0bc-3cc99332c0c2
# 1738 2021-08-04 23:15:21.425431+00:00  8669ac67-c9e3-4b4c-add7-3d55ca7386b1
#
#      traffic_source  product_id  quantity  item_price payment_status
# 1734         MOBILE         NaN       NaN         NaN           None
# 1735         MOBILE     17642.0       1.0    163920.0           None
# 1736         MOBILE         NaN       NaN         NaN        Success
# 1737         MOBILE         NaN       NaN         NaN           None
# 1738         MOBILE         NaN       NaN         NaN           None

# %% [markdown]
# ### Drop the columns since I will not be needing them for my analysis and the majority of data is missing.

# %%
df = df.drop(columns= ['product_id', 'quantity','item_price'])

# %%
df.head()
# Out:
#                                 session_id   event_name  \
# 1734  9586a822-62e6-43e3-80a8-604e817daad4     HOMEPAGE
# 1735  9586a822-62e6-43e3-80a8-604e817daad4  ADD_TO_CART
# 1736  9586a822-62e6-43e3-80a8-604e817daad4      BOOKING
# 1737  9586a822-62e6-43e3-80a8-604e817daad4       SCROLL
# 1738  9586a822-62e6-43e3-80a8-604e817daad4       SEARCH
#
#                            event_time                              event_id  \
# 1734 2021-08-04 07:31:35.425431+00:00  a78f83d7-489c-4123-808b-9fca01c51847
# 1735 2021-08-04 15:25:09.425431+00:00  f79f8b9f-c044-41da-add5-ed2e511585ce
# 1736 2021-08-06 06:57:08.425431+00:00  544bfa6a-9bf3-410a-b7c5-ad430ab756ae
# 1737 2021-08-04 15:24:06.425431+00:00  2553f0a6-80cf-4df5-b0bc-3cc99332c0c2
# 1738 2021-08-04 23:15:21.425431+00:00  8669ac67-c9e3-4b4c-add7-3d55ca7386b1
#
#      traffic_source payment_status
# 1734         MOBILE           None
# 1735         MOBILE           None
# 1736         MOBILE        Success
# 1737         MOBILE           None
# 1738         MOBILE           None

# %%
df.to_csv('click_stream_cleaned.csv', index=False)
